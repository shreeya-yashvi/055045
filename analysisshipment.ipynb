# %% [markdown]
# # Project Information
#
# **Title**: Data Visualization (Dashboard) with Python using Pandas, Numpy, Matplotlib & Streamlit Libraries
#
# **Student Name and Roll No.**: Shreeya Yashvi (055045)

# %% [markdown]
# # Description Of Data
#
# 1. **Data Source**: [Kaggle Imports Exports Dataset](https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000)
# 2. **Data Size**: 32,016
# 3. **Data Dimension**: The dataset contains 15,000 rows and a sample of 3,001 rows and 16 variables (columns) have been taken from this dataset to test the objectives.
# 4. **Data Type**: The data is a panel data as it contains various entries recorded over a period of time.
# 5. **Data Variable Type**: The data contains **3 integer type variables** ('Quantity', 'Customs_Code', 'Invoice_Number'), **2 float type variables** ('Value', 'Weight'), and **9 text type** variables ('Transaction_ID', 'Country', 'Product', 'Import_Export', 'Category', 'Port', 'Shipping_Method', 'Supplier', 'Customer', 'Payment_Terms', 'Date').
# 6. **The Variables can be divided into**:
#    - **Index Variables**: ('Transaction_ID', 'Customs_Code', 'Invoice_Number')
#    - **Ordinal Variables**: ('Date')
#    - **Nominal Variables**: ('Country', 'Product', 'Import_Export', 'Category', 'Port', 'Shipping_Method', 'Supplier', 'Customer', 'Payment_Terms')
#    - **Non-Categorical Variables**: ('Quantity', 'Value', 'Weight')

# %% [markdown]
# # Objective of the project
# The project aims to explore the factors influence trade efficiency in different products and countries for the suppliers by examining the shipping method, payment terms, product categories and the relationship between product Quantity, value and weight. We are trying to uncover Trends and assess commonly traded goods. By observing variations, the analysis will offer insights to respective managers/ suppliers for further decision-making to enhance trade.

# %% [markdown]
# # Observations and Managerial Insights
#
# ## bar chart to visualize the top 5 importing and exporting countries by number of products
# 1. **Focus on Bilateral Agreements**:
#    Countries like San Marino (which ranks high in imports) and Congo (which ranks high in exports) could benefit from enhanced bilateral trade agreements. One should consider creating favorable trade terms between these nations to ensure a steady flow of goods and to strengthen partnerships.
#
# 2. **Optimizing Trade Routes**:
#    Since Korea is a leader in both imports and exports, managers could focus on optimizing supply chains and logistics involving this country to reduce costs and improve efficiency. Establishing a regional logistics hub in Korea could be a strategic move to capitalize on the trade volume.
#
# 3. **Market Expansion and Targeting**:
#    San Marino, which shows high import activity, can be targeted for market expansion. This indicates a strong demand for products, and businesses could focus their sales and marketing efforts on this region to capture a larger market share.
#
# 4. **Risk Diversification**:
#    Relying on Korea for the majority of imports or exports introduces concentration risk. Managers may want to diversify their sourcing or export destinations by exploring other emerging markets with similar demand to reduce the risk associated with over-reliance on one country.
#
# 5. **Utilizing Trade Opportunities for High Export Countries**:
#    Countries like Korea and Congo, which are leading in exports, should focus on utilizing their established trade networks to enter new markets. By leveraging their production strength, they can diversify their export destinations, particularly in developing regions where demand is growing. Additionally, they could invest in branding and quality improvements to create a competitive advantage in high-value markets.

# %% [markdown]
# ## # which product category can be dealt in for liquidity?
# The stacked bar chart displays the distribution of payment terms across various product categories, allowing us to analyze the dominant payment patterns and identify which product categories have the most liquid payment methods:
#
# ### Analysis:
#
# 1. **Dominant Payment Terms**:
#    Some categories show a higher reliance on particular payment terms. For instance, categories like Machinery or Electronics may exhibit more instances of specific terms like "Net 30" or "Net 60," suggesting that buyers in these industries often negotiate similar payment periods.
#
# 2. **Most Liquid Payment Methods**:
#    The presence of Prepaid or Cash on Delivery payment terms indicates higher liquidity since payments are either made upfront or immediately upon receipt. Categories like Clothing and Toys appear to have a higher frequency of "Prepaid" or "Cash on Delivery" compared to others, indicating more liquid payment methods and potentially shorter payment cycles.
#
# 3. **Credit-based Terms**:
#    Categories such as Furniture or Machinery may be leaning towards longer credit-based terms like "Net 60," indicating that these product categories might involve bulk orders or expensive items that require extended payment flexibility.
#
# ### Key Findings and Insights:
#
# 1. **Dominant Payment Terms Across Categories**:
#    Different product categories demonstrate preferences for specific payment terms, highlighting varying purchasing behaviors and credit requirements. Net 30 is one of the most frequently used payment terms across several product categories, such as Electronics and Machinery. This suggests that a 30-day credit period is commonly acceptable for buyers in these segments, possibly indicating well-established trust and longer-term relationships between buyers and sellers. Net 60 is also used significantly, especially in product categories such as Furniture and Machinery. These are typically higher-value products, which may require extended credit terms for buyers to manage cash flow efficiently.
#
# 2. **Liquidity Analysis – Prepaid and Cash on Delivery**:
#    Categories such as Clothing and Toys show a higher frequency of Prepaid and Cash on Delivery (COD) payment terms. This indicates greater liquidity and shorter payment cycles for these categories, possibly because they involve relatively lower-value goods that buyers can pay upfront without significant cash flow concerns. Clothing seems to be a highly liquid category, with a noticeable reliance on COD and prepaid payment methods. This suggests that buyers in this segment prefer settling transactions quickly, reducing risks for sellers.
#
# 3. **Credit-based Payment Trends**:
#    Product categories like Furniture and Machinery tend to rely more on credit-based terms such as Net 60. This might be due to the nature of these products being relatively expensive and often sold in bulk, necessitating more flexible payment arrangements. The dominance of Net 60 in Machinery indicates that these transactions often require financing, as machinery purchases are typically capital investments that require longer repayment terms.
#
# 4. **Implications for Cash Flow Management**:
#    - **High Liquidity Segments**: Sellers dealing in categories like Toys and Clothing benefit from faster cash flow turnover since they receive payments immediately or within a short time frame. This may indicate a lower risk for these sellers in terms of delayed payments and can help sustain business liquidity.
#    - **Low Liquidity Segments**: On the other hand, sellers in Furniture and Machinery need to accommodate extended credit periods, which could impact their cash flow if not managed properly. These sellers need to have robust credit assessment mechanisms to avoid defaults and ensure timely collections.
#
# 5. **Buyer-Seller Relationships and Negotiation Insights**:
#    Categories with longer credit terms may indicate well-established relationships between buyers and sellers, where the trust level allows for more extended repayment schedules. Short-term payment terms (such as Prepaid and Net 30) in categories like Clothing could indicate transactions with newer customers or high turnover products where immediate payment is critical to reduce risk.
#
# 6. **Strategic Insights for Business Operations**:
#    - **Risk Mitigation**: Sellers dealing in categories with longer credit terms should focus on robust risk mitigation strategies, such as credit insurance or strict payment follow-up, to ensure liquidity.
#    - **Sales Strategies**: Categories where Prepaid is dominant could explore providing slight credit flexibility to attract more customers without affecting cash flow significantly. Conversely, categories with extended credit terms might consider offering early payment discounts to motivate quicker settlements.
#
# ### Conclusion
# The analysis of payment terms across product categories reveals that Clothing and Toys are the most liquid product segments, likely due to their low value and fast-moving nature, allowing for immediate or COD payments. Categories such as Furniture and Machinery rely more heavily on credit terms, which reflects the high-value nature of these products and the need for flexible repayment options.
#
# These findings provide insights into the financial behaviors associated with different products, which can be utilized to inform sales policies, credit management, and relationship-building strategies within each product segment. For instance, sellers can use these insights to decide which payment terms to offer to enhance customer relationships while managing risk effectively.

# %% [markdown]
# ## the pie chart depicting product categories and the number of products in each category
#
# Based on the pie chart depicting the distribution of products across product categories, here are some managerial insights for suppliers, both importers and exporters:
#
# 1. **Diversification of Product Offerings**:
#    The proportion of products across different categories provides insights into the market's current focus. If the chart reveals a dominant category, it indicates an opportunity for suppliers to diversify their offerings. For example, if most products are concentrated in the "Toys" or "Electronics" category, importers and exporters should consider expanding to underrepresented categories like "Furniture" to tap into less competitive spaces.
#
# 2. **Market Opportunity Identification**:
#    If certain categories show a smaller share in the pie chart, there might be untapped market potential or less competition in those areas. Suppliers can use this information to identify potential growth opportunities, especially for exporters trying to target international markets with fewer competitors.
#
# 3. **Strategic Alliances and Targeted Procurement**:
#    Exporters could form strategic partnerships with suppliers offering products in high-demand categories. For example, if "Toys" shows a significant share, exporters could negotiate exclusive contracts with manufacturers in this segment, ensuring consistent supply and competitive pricing.
#
# 4. **Pricing Strategy Adjustments**:
#    If a particular category, such as "Electronics," is in high demand, suppliers might consider dynamic pricing to maximize revenue during peak periods. Conversely, lower-represented categories may benefit from promotional pricing to stimulate market interest.
#
# 5. **Logistics and Inventory Management**:
#    Importers and exporters must manage inventory effectively based on the category distribution. Categories with smaller proportions might require just-in-time (JIT) inventory to minimize holding costs, whereas categories with a larger share, such as "Machinery," might need more significant warehouse capacity and streamlined logistics processes.
#
# 6. **Resource Allocation**:
#    Suppliers can align their resources based on the distribution insights. For instance, allocating more marketing, manpower, or logistics to categories with higher product counts could drive increased market penetration. For categories with fewer products, suppliers might allocate resources toward innovation or niche marketing.
#
# 7. **Tailored Marketing Campaigns**:
#    Knowing which product categories are more prominent allows for better-targeted marketing campaigns. For example, if "Furniture" and "Clothing" categories are underrepresented, suppliers can focus marketing campaigns on these products, leveraging specific festivals, seasons, or promotions to boost sales.
#
# 8. **Innovation Opportunities**:
#    Categories with lower shares in the chart present opportunities for innovation. Suppliers can introduce new product lines or enhance existing products to fill gaps in the market, capturing unmet consumer needs and differentiating themselves from competitors.
#
# These insights can help importers and exporters make data-driven decisions, allowing them to effectively allocate resources, balance risks, capitalize on opportunities, and ultimately gain a competitive edge in the market.

# %% [markdown]
# ## the demand for each product category across different months using a line plot
#
# Based on the chart depicting the monthly demand for product categories, here are managerial insights:
#
# 1. **Seasonal Demand Trends**:
#    Different product categories exhibit peak demand at different times of the year. For instance, Clothing shows a significant increase in demand around December, while Electronics peaks in September. Suppliers can use these trends to ensure sufficient inventory is available during peak months to capitalize on heightened demand.
#
# 2. **Product-Specific Campaigns**:
#    Marketing campaigns should be tailored to these seasonal trends. For example, Machinery shows a strong demand in June and August, suggesting targeted marketing and promotions during these periods could be effective. Conversely, campaigns for products with lower demand in particular months could focus on discounting to boost sales.
#
# 3. **Optimized Resource Allocation**:
#    Categories such as Machinery and Electronics have more pronounced fluctuations throughout the year, while Clothing is more consistent. This variation indicates the need for flexible resource allocation—staffing, warehousing, and logistics should adjust according to the category's demand pattern to maximize efficiency and reduce costs.
#
# 4. **Stock and Procurement Planning**:
#    Products like Toys and Machinery experience distinct demand spikes, which suggests the need for proactive procurement and production strategies to meet seasonal peaks without facing stockouts. By analyzing these demand patterns, suppliers can improve lead times and mitigate risks related to fluctuating availability of raw materials or production capacity constraints.

# %% [markdown]
# ##  Quantity across Shipping Methods
#
# Based on the box plot depicting the quantity distribution across shipping methods, here are the insights regarding which shipping method is preferred for heavier and lighter quantities:
#
# 1. **Land Shipping**:
#    The distribution of quantities for land shipments shows a higher median and a wider range, indicating that land shipping is frequently used for both heavy and light quantities. The box plot shows that land is a versatile shipping option, accommodating a broad range of quantities. This makes land shipping a preferred choice for handling heavier quantities due to its capacity to move bulk shipments cost-effectively.
#
# 2. **Air Shipping**:
#    Air shipping exhibits a slightly lower median compared to land shipping, and it shows less variability in quantities. This suggests that air shipping is often preferred for medium to light quantities, where faster delivery times are required. Air tends to be more expensive, making it a favorable choice for lighter shipments that need to reach destinations quickly.
#
# 3. **Sea Shipping**:
#    The sea shipping method also displays a wide range of quantities similar to land but with a slightly lower median. Sea shipping is typically used for bulk quantities, especially when cost efficiency is prioritized over speed. It is suitable for heavy shipments that do not require urgent delivery.
#
# ### Summary:
# - **Land Shipping**: Preferred for a broad range of quantities, especially heavier shipments, due to cost efficiency.
# - **Air Shipping**: Preferred for lighter quantities that require faster delivery times.
# - **Sea Shipping**: Suitable for heavy quantities, particularly when cost savings are prioritized and delivery timelines are flexible.

# %%
import pandas as pd

# Load the dataset
file_path = "C:/Users/235556/OneDrive/Desktop/New folder/group project.csv"
df = pd.read_csv("C:/Users/235556/OneDrive/Desktop/New folder/group project.csv")

# Take up random data of 3001 records with random state 55045
sample_df = df.sample(n=3001, random_state=55045)

# Displaying the first few rows of the sampled data
sample_df.head()
# Out:
#                              Transaction_ID                 Country  Product  \
# 3408   b69da0da-c0f4-47a4-bdb4-aa2cf9a31bd2                  Israel    cover
# 12310  811a7096-f5ab-4953-9920-cdf25a3d9982  Libyan Arab Jamahiriya    might
# 1968   d2a679ac-f061-4e72-a28a-c24d99ac7f9f  Bosnia and Herzegovina   entire
# 13559  dbc9d8c8-2784-4b6a-8639-6e50aa7cae9f               Indonesia    start
# 427    142a6c95-d908-4a42-b448-0761505e9c9b                 Bolivia  general
#
#       Import_Export  Quantity    Value        Date   Category        Port  \
# 3408         Import      2548  5175.12  21-01-2021  Machinery   Port Mary
# 12310        Export      2766  7343.97  09-09-2023  Machinery  Lake Shane
# 1968         Export      9573  3890.53  06-07-2020   Clothing   Jamiefurt
# 13559        Export      6295  8745.30  29-06-2024       Toys  Ambershire
# 427          Import      1802  9122.77  29-10-2020   Clothing  South Mark
#
# ...

# %%
#Data Variable Type:-
sample_df.info()
#decimal(02), integer(03), text(11)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3001 entries, 3408 to 12626
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   3001 non-null   object
#  1   Country          3001 non-null   object
#  2   Product          3001 non-null   object
#  3   Import_Export    3001 non-null   object
#  4   Quantity         3001 non-null   int64
#  5   Value            3001 non-null   float64
#  6   Date             3001 non-null   object
#  7   Category         3001 non-null   object
#  8   Port             3001 non-null   object
#  9   Customs_Code     3001 non-null   int64
#  10  Weight           3001 non-null   float64
#  11  Shipping_Method  3001 non-null   object
#  12  Supplier         3001 non-null   object
#  13  Customer         3001 non-null   object
#  14  Invoice_Number   3001 non-null   int64
#  15  Payment_Terms    3001 non-null   object
# dtypes: float64(2), int64(3), object(11)
# ...

# %%
#Data Dimension:-
sample_df.shape
# Out:
# (3001, 16)

# %%
#Data size:- 48016 data
sample_df.size
# Out:
# 48016

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Count the number of products for each country for Import and Export separately
import_data = sample_df[sample_df['Import_Export'] == 'Import']['Country'].value_counts().nlargest(5)
export_data = sample_df[sample_df['Import_Export'] == 'Export']['Country'].value_counts().nlargest(5)

# Create a bar chart to visualize the top 5 importing and exporting countries by number of products
plt.figure(figsize=(14, 8))

plt.bar(import_data.index, import_data.values, alpha=0.6, label='Import', color='blue')
plt.bar(export_data.index, export_data.values, alpha=0.6, label='Export', color='green')

plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Number of Products')
plt.title('Top 5 Countries by Number of Products Imported and Exported')
plt.legend()
plt.tight_layout()

plt.show()

# %%
# which product category can be dealt in for liquidity?
# Count the number of occurrences of each payment term for each product category
payment_terms_category = sample_df.groupby(['Category', 'Payment_Terms']).size().unstack(fill_value=0)

# Plot a stacked bar chart to visualize payment terms across product categories
payment_terms_category.plot(kind='bar', stacked=True, figsize=(14, 8))

plt.xlabel('Product Category')
plt.ylabel('Number of Transactions')
plt.title('Payment Terms Across Product Categories')
plt.xticks(rotation=45)
plt.legend(title='Payment Terms')
plt.tight_layout()

plt.show()

# %%
# the non-categorical variables
non_cat = sample_df[['Quantity', 'Value', 'Weight']]

# Displaying descriptive statistics for the updated non-categorical variables
non_cat_summary_updated = non_cat.describe()
non_cat_summary_updated
# Out:
#           Quantity        Value       Weight
# count  3001.000000  3001.000000  3001.000000
# mean   5004.288570  4987.591306  2487.575402
# std    2835.040951  2871.889517  1456.195585
# min       6.000000   104.490000     6.480000
# 25%    2547.000000  2454.210000  1223.760000
# 50%    5038.000000  4947.090000  2432.420000
# 75%    7437.000000  7432.910000  3738.940000
# max    9996.000000  9980.350000  4999.930000

# %%
import matplotlib.pyplot as plt

# Visualizing the non-categorical variables using box plots
plt.figure(figsize=(15, 10))

for i, column in enumerate(non_cat, 1):
    plt.subplot(2, 3, i)  # Create a grid for the subplots (2 rows, 3 columns)
    non_cat.boxplot(column=column, showmeans=True, meanline=True, meanprops={"linestyle": "--", "color": "red"})
    plt.title(f"Box Plot of {column}")

plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the box plots for the non-categorical variables (Quantity, Value, Weight), here are some insights and anomalies:
#
# 1. Quantity
# Insights:
# The distribution shows a wide range of values, with the median roughly in the middle.
# The spread (interquartile range) suggests a moderate variation in quantities.
# Anomalies:
# There are numerous outliers on the higher end of the distribution, which indicates some unusually large quantities compared to the rest.
# 2. Value
# Insights:
# The Value distribution has a median slightly below the middle of the box, suggesting a slight skew towards lower transaction values.
# Most of the values are concentrated within a particular range, with a smaller interquartile range.
# Anomalies:
# Significant outliers are present, indicating the presence of transactions with unusually high values.
# The whiskers extend to a smaller range compared to the number of outliers, indicating that these high-value transactions are exceptional cases.
# 3. Weight
# Insights:
# The median is positioned around the middle, showing a fairly balanced distribution of weights.
# The spread suggests a wide range of shipment weights.
# Anomalies:
# There are several high-value outliers, suggesting some unusually heavy shipments compared to the majority.
# The concentration around the interquartile range is denser, while the whiskers are relatively short, which implies the presence of a few very heavy shipments.
# General Observations:
# All three variables have a considerable number of outliers, which may indicate some exceptional cases or data-entry errors.
# The presence of outliers suggests potential heterogeneity in the dataset—likely due to diverse product categories, types of shipments, or customer needs.

# %%
# Group the data by Category and count the number of products in each category
category_product_count = sample_df.groupby('Category')['Product'].nunique().reset_index()

# Plot the pie chart depicting product categories and the number of products in each category
plt.figure(figsize=(10, 8))
plt.pie(category_product_count['Product'], labels=category_product_count['Category'], autopct='%1.1f%%', startangle=140, colors=sns.color_palette('viridis'))
plt.title('Distribution of Products across Product Categories')
plt.show()

# %%
# Convert the 'Date' column to datetime format for easier manipulation
sample_df['Date'] = pd.to_datetime(sample_df['Date'], format='%d-%m-%Y')

# Extract the month from the Date to understand seasonal trends
sample_df['Month'] = sample_df['Date'].dt.month

# Group the data by Month and calculate the sum of Quantity for each month
monthly_trade_volume = sample_df.groupby('Month')['Quantity'].sum().reset_index()

# Plot the seasonal trade volume across different months using a line plot
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_trade_volume, x='Month', y='Quantity', marker='o', color='b')
plt.title('Seasonal Trade Volume by Month')
plt.xlabel('Month')
plt.ylabel('Total Trade Volume (Quantity)')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# Group the data by Month and Category, and calculate the sum of Quantity for each combination
monthly_category_trade_volume = sample_df.groupby(['Month', 'Category'])['Quantity'].sum().reset_index()

# Plot the demand for each product category across different months using a line plot
plt.figure(figsize=(15, 8))
sns.lineplot(data=monthly_category_trade_volume, x='Month', y='Quantity', hue='Category', marker='o', palette='viridis')
plt.title('Monthly Demand for Product Categories')
plt.xlabel('Month')
plt.ylabel('Total Trade Volume (Quantity)')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.legend(title='Product Category')
plt.show()

# Filter the data for export transactions
export_data = sample_df[sample_df['Import_Export'] == 'Export']

# Group the export data by Month and calculate the sum of Value for each month
monthly_export_value = export_data.groupby('Month')['Value'].sum().reset_index()

# Plot the total value of exports for each month using a line plot
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_export_value, x='Month', y='Value', marker='o', color='g')
plt.title('Monthly Export Value')
plt.xlabel('Month')
plt.ylabel('Total Export Value')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# %%
# Visualizing Quantity across Shipping Methods using a box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Shipping_Method', y='Quantity', data=sample_df, showmeans=True, meanprops={"marker": "o", "markerfacecolor": "red", "markeredgecolor": "red"})

# Setting plot labels and title
plt.xlabel('Shipping Method')
plt.ylabel('Quantity')
plt.title('Quantity Distribution Across Shipping Methods')
plt.show()
